# %%
# !nvidia-smi

# %%
# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ROOT_DIR = '/content/gdrive/My Drive/data'

# %%
import os
model = YOLO('yolov8n.pt')

results = model.train(data=os.path.join(ROOT_DIR, 'data.yaml'), epochs=50, imgsz=900, batch=2)
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 76.6MB/s]
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !nvidia-smi

# %%
# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ROOT_DIR = '/content/gdrive/My Drive/data'

# %%
import os
model = YOLO('yolov8n.pt')

results = model.train(data=os.path.join(ROOT_DIR, 'data.yaml'), epochs=50, imgsz=900, batch=2)
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 76.6MB/s]
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !nvidia-smi

# %%
# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ROOT_DIR = '/content/gdrive/My Drive/data'

# %%
import os
model = YOLO('yolov8n.pt')

results = model.train(data=os.path.join(ROOT_DIR, 'data.yaml'), epochs=50, imgsz=900, batch=2)
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 76.6MB/s]
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !nvidia-smi

# %%
# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ROOT_DIR = '/content/gdrive/My Drive/data'

# %%
import os
model = YOLO('yolov8n.pt')

results = model.train(data=os.path.join(ROOT_DIR, 'data.yaml'), epochs=50, imgsz=900, batch=2)
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 76.6MB/s]
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !nvidia-smi

# %%
# !nvidia-smi

# %%
# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ROOT_DIR = '/content/gdrive/My Drive/data'

# %%
import os
model = YOLO('yolov8n.pt')

results = model.train(data=os.path.join(ROOT_DIR, 'data.yaml'), epochs=50, imgsz=900, batch=2)
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 76.6MB/s]
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !nvidia-smi

# %%
# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ROOT_DIR = '/content/gdrive/My Drive/data'

# %%
import os
model = YOLO('yolov8n.pt')

results = model.train(data=os.path.join(ROOT_DIR, 'data.yaml'), epochs=50, imgsz=900, batch=2)
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 76.6MB/s]
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !nvidia-smi

# %%
# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ROOT_DIR = '/content/gdrive/My Drive/data'

# %%
import os
model = YOLO('yolov8n.pt')

results = model.train(data=os.path.join(ROOT_DIR, 'data.yaml'), epochs=50, imgsz=900, batch=2)
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 76.6MB/s]
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import shutil
source_path = '/content/runs'
destination_path = '/content/gdrive/My Drive/data/runs'
shutil.copytree(source_path, destination_path)
# Out:
# '/content/gdrive/My Drive/data/runs'

# %%
model_path = '/content/gdrive/My Drive/data/runs/detect/train/weights/best.pt'
from ultralytics import YOLO


model = YOLO(model_path)

# Define path to the image file
source = 'path/to/image.jpg'

# Run inference on the source
results = model(source)  # list of Results objects
# Out:
# image 1/1 /content/gdrive/My Drive/data/evaluation/ardmega.jpg: 832x928 1 Button, 9 Capacitors, 8 Connectors, 7 ICs, 17 Resistors, 586.4ms
# Speed: 18.4ms preprocess, 586.4ms inference, 1.5ms postprocess per image at shape (1, 3, 832, 928)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-6b1f60caafd0> in <cell line: 20>()
#      22     results = model(image_path)
#      23     save_path = Path(output_images_path) / f"{image_path.stem}_output.jpg"
# ---> 24     results.render()[0].savefig(save_path)
#      25     plt.close('all')
#      26
#
# AttributeError: 'list' object has no attribute 'render'
